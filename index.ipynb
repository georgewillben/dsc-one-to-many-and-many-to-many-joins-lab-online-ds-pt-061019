# %% [markdown]
# Some of the code in this lab was copied from the solution at https://github.com/learn-co-curriculum/dsc-one-to-many-and-many-to-many-joins-lab/tree/solution

# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here
c.execute(''' SELECT firstName, lastName, city, state FROM
                employees JOIN offices USING(officeCode) ORDER BY firstName, lastName ''')
c.fetchall()
# Out:
# [('Andy', 'Fixter', 'Sydney', ''),
#  ('Anthony', 'Bow', 'San Francisco', 'CA'),
#  ('Barry', 'Jones', 'London', ''),
#  ('Diane', 'Murphy', 'San Francisco', 'CA'),
#  ('Foon Yue', 'Tseng', 'NYC', 'NY'),
#  ('George', 'Vanauf', 'NYC', 'NY'),
#  ('Gerard', 'Bondur', 'Paris', ''),
#  ('Gerard', 'Hernandez', 'Paris', ''),
#  ('Jeff', 'Firrelli', 'San Francisco', 'CA'),
#  ('Julie', 'Firrelli', 'Boston', 'MA'),
#  ('Larry', 'Bott', 'London', ''),
#  ('Leslie', 'Jennings', 'San Francisco', 'CA'),
#  ('Leslie', 'Thompson', 'San Francisco', 'CA'),
#  ('Loui', 'Bondur', 'Paris', ''),
#  ('Mami', 'Nishi', 'Tokyo', 'Chiyoda-Ku'),
#  ('Martin', 'Gerard', 'Paris', ''),
#  ('Mary', 'Patterson', 'San Francisco', 'CA'),
#  ('Pamela', 'Castillo', 'Paris', ''),
#  ('Peter', 'Marsh', 'Sydney', ''),
#  ('Steve', 'Patterson', 'Boston', 'MA'),
#  ('Tom', 'King', 'Sydney', ''),
#  ('William', 'Patterson', 'Sydney', ''),
#  ('Yoshimi', 'Kato', 'Tokyo', 'Chiyoda-Ku')]

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here
c.execute(''' SELECT contactFirstName, contactLastName, orderNumber, orderDate, status FROM
                customers JOIN orders USING(customerNumber) GROUP BY customerNumber ''')
c.fetchall()
# Out:
# [('Carine ', 'Schmitt', '10123', '2003-05-20', 'Shipped'),
#  ('Jean', 'King', '10124', '2003-05-21', 'Shipped'),
#  ('Peter', 'Ferguson', '10120', '2003-04-29', 'Shipped'),
#  ('Janine ', 'Labrune', '10275', '2004-07-23', 'Shipped'),
#  ('Jonas ', 'Bergulfsen', '10103', '2003-01-29', 'Shipped'),
#  ('Susan', 'Nelson', '10113', '2003-03-26', 'Shipped'),
#  ('Roland', 'Keitel', '10101', '2003-01-09', 'Shipped'),
#  ('Julie', 'Murphy', '10111', '2003-03-25', 'Shipped'),
#  ('Kwai', 'Lee', '10107', '2003-02-24', 'Shipped'),
#  ('Diego ', 'Freyre', '10104', '2003-01-31', 'Shipped'),
#  ('Christina ', 'Berglund', '10112', '2003-03-24', 'Shipped'),
#  ('Jytte ', 'Petersen', '10105', '2003-02-11', 'Shipped'),
#  ('Mary ', 'Saveley', '10194', '2003-11-25', 'Shipped'),
#  ('Eric', 'Natividad', '10117', '2003-04-16', 'Shipped'),
#  ('Jeff', 'Young', '10127', '2003-06-03', 'Shipped'),
#  ('Kelvin', 'Leong', '10272', '2004-07-20', 'Shipped'),
# ...

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute(''' SELECT contactFirstName, contactLastName, amount, paymentDate FROM
            customers JOIN payments USING(customerNumber) ORDER BY amount DESC ''')
c.fetchall()
# Out:
# [('Violeta', 'Benitez', '9977.85', '2003-11-08'),
#  ('Ben', 'Calaghan', '9821.32', '2003-10-17'),
#  ('Leslie', 'Taylor', '9658.74', '2004-12-06'),
#  ('Sean', 'Clenahan', '9415.13', '2004-07-28'),
#  ('Roland ', 'Mendel', '8807.12', '2005-05-03'),
#  ('Julie', 'Brown', '85559.12', '2003-11-03'),
#  ('Susan', 'Nelson', '85410.87', '2004-08-28'),
#  ('Veysel', 'Oeztan', '85024.46', '2003-12-03'),
#  ('Susan', 'Nelson', '83598.04', '2005-04-16'),
#  ('Wing', 'Huang', '8307.28', '2005-01-18'),
#  ('Peter', 'Ferguson', '82261.22', '2004-12-15'),
#  ('Valarie', 'Thompson', '80375.24', '2004-03-15'),
#  ('Steve', 'Thompson', '7678.25', '2003-12-09'),
#  ('Christina ', 'Berglund', '7674.94', '2003-04-09'),
#  ('Franco', 'Ricotti', '7612.06', '2004-02-17'),
#  ('Peter', 'Ferguson', '7565.08', '2003-05-31'),
#  ('Mike', 'Graham', '75020.13', '2005-05-23'),
#  ('Roland', 'Keitel', '7466.32', '2004-11-18'),
#  ('Thomas ', 'Smith', '7310.42', '2004-01-31'),
# ...

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here
c.execute(''' SELECT contactFirstName, contactLastName productName, quantityOrdered, orderDate FROM
            customers JOIN orders USING(customerNumber) JOIN orderDetails USING(orderNumber) JOIN
            products USING(productCode) ORDER BY orderDate DESC ''')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
print(len(df))
df.head()
# Out:
# 2996
#   contactFirstName productName quantityOrdered   orderDate
# 0          Janine      Labrune              38  2005-05-31
# 1          Janine      Labrune              33  2005-05-31
# 2          Janine      Labrune              28  2005-05-31
# 3          Janine      Labrune              38  2005-05-31
# 4          Janine      Labrune              19  2005-05-31

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
